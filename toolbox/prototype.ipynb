# %%
from src.analysis import process_folder, visualize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tom\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
process_folder(model_name="tfidf")
# Out:
# Processing ACCOR_RI_2023_MEL_UK.parquet
# Processing air-liquide-document-enregistrement-universel-2023-interactif.parquet
# Processing Airbus-Annual-Report-2023.parquet
# Processing arcelor-mittal-integrated-annual-review-2023.parquet
# Processing axa_ri2023_accessibleb_va.parquet

# %%
visualize(model_name="tfidf")
# Out:
# Visualizing ACCOR_RI_2023_MEL_UK_paragraphs_tfidf.parquet
# c:\Users\tom\PycharmProjects\greenNLP\greenNLP\analysis.py:125: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), ha="right", rotation=45)
# c:\Users\tom\PycharmProjects\greenNLP\greenNLP\analysis.py:154: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), ha="right", rotation=45)
# Visualizing air-liquide-document-enregistrement-universel-2023-interactif_paragraphs_tfidf.parquet
# c:\Users\tom\PycharmProjects\greenNLP\greenNLP\analysis.py:125: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), ha="right", rotation=45)
# c:\Users\tom\PycharmProjects\greenNLP\greenNLP\analysis.py:154: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), ha="right", rotation=45)
# Visualizing Airbus-Annual-Report-2023_paragraphs_tfidf.parquet
# c:\Users\tom\PycharmProjects\greenNLP\greenNLP\analysis.py:125: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), ha="right", rotation=45)
# c:\Users\tom\PycharmProjects\greenNLP\greenNLP\analysis.py:154: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), ha="right", rotation=45)
# Visualizing arcelor-mittal-integrated-annual-review-2023_paragraphs_tfidf.parquet
# c:\Users\tom\PycharmProjects\greenNLP\greenNLP\analysis.py:125: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), ha="right", rotation=45)
# c:\Users\tom\PycharmProjects\greenNLP\greenNLP\analysis.py:154: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), ha="right", rotation=45)
# Visualizing axa_ri2023_accessibleb_va_paragraphs_tfidf.parquet
# c:\Users\tom\PycharmProjects\greenNLP\greenNLP\analysis.py:125: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), ha="right", rotation=45)
# c:\Users\tom\PycharmProjects\greenNLP\greenNLP\analysis.py:154: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), ha="right", rotation=45)
